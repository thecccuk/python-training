# %% [markdown]
# # UK surface transport emissions: exercises
#
# On the course you rebuilt the Climate Change Committee's charts for **electricity supply**. These post-training exercises use **surface transport** data instead - cars, vans, HGVs and rail. They draw on both of the courses you attended, *Programming with Python* and *Data Visualisation with Python*.
#
# The questions come in two groups:
#
# - **Q1-Q7** work through the analysis a step at a time. Everything you need is in your course notebooks.
# - **Q8-Q10** are marked *Harder*. They build on Q1-Q7.
#
# ## Setting up
#
# On the course everything was installed for you. On your own machine, work in a **conda environment** - a self-contained set of packages for one project, so that projects can't break each other with conflicting versions.
#
# - Open the Anaconda Prompt (Start menu, search "Anaconda"), and create an environment:
#
#   ```
#   conda create -n python-training python
#   ```
#
# - You may be asked to approve some steps. Enter `y` or `a`, whichever is offered.
#
# - Activate it:
#
#   ```
#   conda activate python-training
#   ```
#
# - Move into the folder holding this notebook, then install the packages listed in `requirements.txt`:
#
#   ```
#   pip install -r requirements.txt
#   ```
#
# - Open **the folder** in VS Code - File > Open Folder, not just the notebook file - then click **Select Kernel** in the top right and choose the `python-training` environment you just created.
#
#   Opening the folder matters: the notebook reads its data and the CCC theme from its own directory, so if VS Code is pointed somewhere else you'll get `No such file or directory` or `No module named 'ccc_theme'`.
#
# ## The data
#
# Sitting alongside this notebook is one `csv` per surface transport subsector - `Cars.csv`, `Vans.csv`, `HGVs.csv`, `Rail.csv` and `Other.csv`. Each has three columns:
#
# | Column | Contents |
# |---|---|
# | `year` | 2008 to 2050 |
# | `series` | `Historical` values (2008-2025) or the projected `Balanced Pathway` (2025-2050) |
# | `emissions` | MtCO2e |
#
# The subsector itself is recorded only in the filename, which matters in Q8.
#
# The data is an extract from the CCC's [Seventh Carbon Budget charts workbook](https://www.theccc.org.uk/publication/the-seventh-carbon-budget/#publication-downloads).
#
# There's no `jrpy.data.load()` here, because the course package isn't installed on your machine - the files are read with `pd.read_csv()` instead. The CCC theme from chapters 2 and 3 of Data Visualisation ships alongside this notebook as `ccc_theme.py`, so `import ccc_theme as ccc` does what `import jrpyvis.ccc_theme as ccc` did in class.
#
# Run the cell below to load the packages you'll need.

# %%
# Run this cell to load the libraries we'll need
import os

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Q1) Get to know the data
#
# ### Q1a)
#
# Read `Cars.csv` into a `DataFrame` called `cars`, and preview it with `.head()`.
#
# ### Q1b)
#
# How many rows and columns does it have? Use `.shape`.
#
# ### Q1c)
#
# What values does the `series` column take? Use `.unique()`.

# %%
# Your Q1a) - Q1c) code here

# %% [markdown]
# ## Q2) Filtering, conditionals and loops
#
# ### Q2a)
#
# Car emissions in 2025 are about 58 MtCO2e. Write an `if` / `elif` / `else` statement that prints `"high"` if a `value` variable is greater than 40, `"medium"` if it is greater than 20, and `"low"` otherwise. Test it by setting different values for the `value` variable.
#
# ### Q2b)
#
# Using `.loc` and a boolean mask, keep only the `Balanced Pathway` rows of `cars`, and store the new `Dataframe` as `pathway`. How many years does it cover? Use `.shape[0]`.
#
# ### Q2c)
#
# Using a single `for` loop, print each year in `pathway` next to its emissions value.
#
# *Hint*: `zip()` lets one loop walk two lists at the same time:
#
# ```python
# for first, last in zip(first_names, last_names):
# ```
#
# Two columns of a `DataFrame` zip together in exactly the same way.
#
# ### Q2d)
#
# Add an `if` statement inside that loop, so it prints only the years where emissions are below 10 MtCO2e.
#
# ### Q2e)
#
# You now have those years by filtering once and then looping. Get to them a second way: starting from `cars`, use `.loc` with a boolean mask - the rows must be in the Balanced Pathway *and* below 10 MtCO2e, joined with `&`.
#
# ### Q2f)
#
# Suppose car emissions simply fell by a steady **10% a year** from their 2025 level of about 58 MtCO2e. How many years would it take to get below 10 MtCO2e?
#
# A `while` loop is the tool here, because you don't know in advance how many steps it will take. You'll need one variable holding the emissions and another counting the years, both updated each time round the loop - the `+=` shorthand is handy for the counter.
#
# Then compare your answer with the real thing: in Q2d) you found the years that actually fall below 10 MtCO2e. Does the CCC's pathway get there faster or slower than a steady 10% cut, and what does that tell you about the shape of it?

# %%
# Your Q2a) code here

# %%
# Your Q2b) - Q2c) code here

# %%
# Your Q2d) - Q2e) code here

# %%
# Your Q2f) code here

# %% [markdown]
# ## Q3) Your first plot
#
# ### Q3a)
#
# Using matplotlib's object-oriented interface, create a line plot of `pathway` emissions against `year`. Start with `fig, ax = plt.subplots()`.
#
# ### Q3b)
#
# Add an $x$ label, a $y$ label with units, and a title.
#
# ### Q3c)
#
# Put an $x$ tick every ten years, from 2030 to 2050.
#
# ### Q3d)
#
# Save your figure as `car_emissions.png`.

# %%
# Your Q3) code here

# %% [markdown]
# ## Q4) The CCC theme
#
# ### Q4a)
#
# The CCC theme ships alongside this notebook. Apply it with `import ccc_theme as ccc`, then draw your Q3 plot again.
#
# One import changes every plot that follows it - a theme is really just a large pile of matplotlib settings, which is why it applies to everything from here on rather than to one figure.
#
# ### Q4b)
#
# Plot **both** series - historical and projected - as two lines on the same axes, using the CCC's own scenario colours, and add a legend.
#
# *Hint*: you'll want a `historical` `DataFrame` to go with `pathway`, made the same way you made that one.
#
# Note that the CCC colours are stored in a `ccc.SCENARIO_COLORS` dictionary, with  `Historical`, `Pathway` and `Baseline` keys. The colours can then be applied to each `ax.plot()` via the `color` argument.
#
# ### Q4c)
#
# The theme is a starting point, not a straitjacket. Make one small change on top of it - nudge the title size with `fontdict`, say - and save the figure.

# %%
# Your Q4a) code here

# %%
# Your Q4b) - Q4c) code here

# %% [markdown]
# ## Q5) Two panels, and a trend line
#
# ### Q5a)
#
# Create a figure with a **1 x 2 grid** of subplots, using `plt.subplots(nrows=1, ncols=2, figsize=(9, 4))`. Plot the historical emissions on the left axes and the Balanced Pathway on the right.
#
# ### Q5b)
#
# Give each panel a title, and label the $x$ axis of each.
#
# *Note*: don't call `fig.tight_layout()` here. The CCC theme turns on matplotlib's *constrained layout*, which handles the spacing already, and calling both prints a warning.
#
# ### Q5c)
#
# Seaborn can add a fitted trend line for you. Use `sns.regplot()` to draw `pathway` emissions against `year`.
#
# ### Q5d)
#
# Draw the same seaborn plot onto a matplotlib `Axes` by passing `ax=`, then add a title and tidy axis labels. That combination - seaborn for the statistics, matplotlib for the finish - is the workflow to remember.

# %%
# Your Q5a) - Q5b) code here

# %%
# Your Q5c) - Q5d) code here

# %% [markdown]
# ## Q6) Five-year budget periods
#
# The CCC sets carbon budgets over **five-year periods**, so a natural way to summarise the pathway is one total per period: 2025-2029, 2030-2034, and so on.
#
# ### Q6a)
#
# What are the total emissions across the whole Balanced Pathway? Use `.sum()`. You can continue to use your `pathway` data from before.
#
# ### Q6b)
#
# Now total just the first period, 2025 to 2029, using `.loc` with a boolean mask.
#
# ### Q6c)
#
# Use a `for` loop over `[2025, 2030, 2035, 2040, 2045]` to build a list called `period_totals`, holding the total for each five-year period.
#
# *Hint*: start with an empty list and `.append()` to it.
#
# ### Q6d)
#
# Draw a bar chart of the five period totals with `ax.bar()`. Label the axes, and add a title.

# %%
# Your Q6a) - Q6b) code here

# %%
# Your Q6c) code here

# %%
# Your Q6d) code here

# %% [markdown]
# ## Q7) Write a function
#
# Everything so far has been about cars. If you wanted the same chart for vans or HGVs you'd be copying and pasting the whole thing - which is the moment to write a function instead.
#
# ### Q7a)
#
# Write a function `plot_subsector(subsector)` that:
#
# - reads that subsector's `csv` file,
# - keeps the Balanced Pathway rows,
# - and plots emissions against year, with labelled axes and a title naming the subsector.
#
# Give it a docstring while you're there.
#
# *Hint*: `pd.read_csv(subsector + ".csv")` opens the right file for a given subsector name.
#
# ### Q7b)
#
# Call it twice, for two different subsectors - `plot_subsector("Vans")` and `plot_subsector("HGVs")`.
#
# ### Q7c)
#
# Give the function a second argument, `series`, that defaults to `"Balanced Pathway"`, so it can plot the historical years too. Check that `plot_subsector("Cars", "Historical")` works.
#
# ### Q7d)
#
# *Harder.* Add a third argument, `ax=None`. If no axes are passed in, the function should make its own figure with `plt.subplots()`; if some are, it should draw on those instead. Have it `return` the axes either way.
#
# That one change is what lets the same function fill a panel of a grid rather than only a figure of its own - which is exactly what Q9 needs.

# %%
# Your Q7) code here

# %% [markdown]
# ## Q8) Every subsector at once
#
# *Harder*
#
# So far you've only looked at cars. The other four subsectors are sitting in this folder as their own `csv` files, with the subsector recorded only in the filename.
#
# ### Q8a)
#
# List the files in the current directory with `os.listdir()`.
#
# ### Q8b)
#
# Loop over that list and print only the names ending in `.csv`, using `.endswith()`.
#
# ### Q8c)
#
# Read `Vans.csv` into a `DataFrame`, and add a `subsector` column recording that it is vans.
#
# ### Q8d)
#
# Now put it together. Starting from an empty `DataFrame`, loop over the files in the directory; for each `csv` file, read it in, add its `subsector` column, and join it on with `pd.concat()`. Call the result `emissions`.
#
# *Hint*: `file.replace(".csv", "")` turns `"Vans.csv"` into `"Vans"`.
#
# ### Q8e)
#
# Check your combined `DataFrame` has **220 rows** - five subsectors, each with 44 years of data.

# %%
# Your Q8a) - Q8b) code here

# %%
# Your Q8c) code here

# %%
# Your Q8d) - Q8e) code here

# %% [markdown]
# ## Q9) Comparing the subsectors
#
# *Harder*
#
# Now you have all five subsectors in one `DataFrame`, you can compare them - which is what the combining in Q8 was for.
#
# ### Q9a)
#
# Create a **2 x 3 grid** of subplots with `figsize=(12, 6)`, and put one subsector in each panel.
#
# If your `plot_subsector()` from Q7d) takes an `ax` argument, the body of the loop is a single line - that's the payoff for writing it that way.
#
# *Hint*: get the list of subsectors with `emissions["subsector"].unique()`, then loop over `zip(axs.flatten(), subsectors)`. `axs` comes back as a 2 x 3 array, and `.flatten()` turns it into a flat list of six so that one loop covers every panel. There are five subsectors and six panels, so hide the spare one with `axs.flatten()[-1].set_visible(False)`.
#
# ### Q9b)
#
# The grid shows each subsector's shape, but not how they compare in size - the panels all have their own $y$ scales, so cars and rail look equally important.
#
# Total each subsector's Balanced Pathway emissions across 2025-2050, and draw a bar chart of the five totals.
#
# - Loop over the subsectors, filter the combined `DataFrame` to one of them, `.sum()` its emissions, and collect the answers in a list, as you did for the budget periods in Q6c).
# - Then `ax.bar()` the totals against the subsector names.
#
# Which subsectors dominate, and by how much? Does anything about the ranking surprise you, given the six panels you just drew?

# %%
# Your Q9a) code here

# %%
# Your Q9b) code here

# %% [markdown]
# ## Q10) Move your code into a script
#
# *Harder*
#
# Notebooks are for exploring and reporting; once you want something reusable and importable, it belongs in a script. Your `plot_subsector()` function is the reusable piece here, so move it into one.
#
# ### Q10a)
#
# Create a file called `transport_tools.py` next to this notebook. In VS Code: **File > New File > Python File**, then save it with that name.
#
# ### Q10b)
#
# Move `plot_subsector()` into the script, docstring and all. Which packages does it depend on? Import them at the top of the script.
#
# ### Q10c)
#
# Import your function back into this notebook with `from transport_tools import plot_subsector`, and check it still draws a chart.
#
# ### Q10d)
#
# Add a block to the end of the script that plots every subsector and saves each one to its own `png`, wrapped in `if __name__ == "__main__":`.
#
# ### Q10e)
#
# Run `%run transport_tools.py` in the cell below, then `import transport_tools`. Only one of them should write out the figures - make sure you can say why.

# %%
# Your Q10c) - Q10e) code here, once you've written transport_tools.py

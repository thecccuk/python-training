# %% [markdown]
# # Chapter 1 Exercises

# %% [markdown]
# Not all questions will require you to write code, you will be able to write
# your answers in the appropriate places. For code answers, write them out into
# the code cells provided.
#
# If you need help:
#
# * Look back through [chapter1/1-demo.ipynb](1-demo.ipynb)
#
# * Consult [chapter 1 of the course notes](../notes.pdf#4)
#
# * Ask for help from your trainer (unmute, message, or private message)

# %% [markdown]
# ### Q1a)

# %% [markdown]
# _Without_ running any code, if `x = [1, 2, 3, 4, 5, 7, 8, 9, 10]`, what would
# `len(x)` return?

# %% [markdown]
# _Type your answer here_

# %%
# Check your answer to Q1a) by running me
x = [1, 2, 3, 4, 5, 7, 8, 9, 10]
len(x)

# %% [markdown]
# ### Q1b)

# %% [markdown]
# _Without_ running any code, if `x = [10, 3, 2, 7]`, what would
# `sorted(x)` return?

# %% [markdown]
# _Type your answer here_

# %%
# Check your answer to Q1b) by running me
x = [10, 3, 2, 7]
sorted(x)

# %% [markdown]
# ### Q1c)

# %% [markdown]
# _Without_ running any code, if `x = [10, 3, 2]` and `y = [4, 8, 1]`, what would
# `x + y` return?

# %% [markdown]
# _Type your answer here_

# %%
# Check your answer to Q1c) by running me
x = [10, 3, 2]
y = [4, 8, 1]
x + y

# %% [markdown]
# ### Q2a)

# %% [markdown]
# _Without_ running any code, if `x = [1, 2, 3, 4, 5, 7, 8, 9, 10]`, what would
# `x[6]` return?

# %% [markdown]
# _Type your answer here_

# %%
# Check your answer to Q2a) by running me
x = [1, 2, 3, 4, 5, 7, 8, 9, 10]
x[6]

# %% [markdown]
# ### Q2b)

# %% [markdown]
# _Without_ running any code, if `x = [1, 2, 3, 4, 5, 7, 8, 9, 10]`, what would
# `x[-3]` return?

# %% [markdown]
# _Type your answer here_

# %%
# Check your answer to Q2b) by running me
x = [1, 2, 3, 4, 5, 7, 8, 9, 10]
x[-3]

# %% [markdown]
# ### Q3)

# %% [markdown]
# Run the following code to import the `jrpyintroduction` course package (we'll
# learn more about packages in the next chapter).

# %%
# Take me for granted for now
import jrpyintroduction as jrpy

# Create list object for this question
y = jrpy.get_numeric_list()

# %% [markdown]
# ### Q3a)

# %% [markdown]
# Extract the 55-th element of the list `y`.
#
# _Hint_: Remember that indexing starts from `0`.

# %%
# Your Q3a) code here

# %% [markdown]
# ### Q3b)

# %% [markdown]
# Using the slice operator `:`, extract the _first 10_ entries of `y`:

# %%
# Your Q3b) code here

# %% [markdown]
# ### Q3c)

# %% [markdown]
# Using the slice operator `:`, extract the entries `y[10]`, `y[11]`, `y[12]`,
# `y[13]`, `y[14]` and `y[15]`.
#
# _Hint_: Remember, the end point is _not_ returned when we slice

# %%
# Your Q3c) code here

# %% [markdown]
# ### Q3d)

# %% [markdown]
# _Harder_

# %% [markdown]
# Compute the arithmetic mean of the values in `y`.
#
# _Hint_: The `sum()` function will be useful here.

# %%
# Your Q3d) code here

# %% [markdown]
# ### Q3e)

# %% [markdown]
# _Harder_

# %% [markdown]
# Extract the 55-th _smallest_ element of `y`.

# %%
# Your Q3e) code here

# %% [markdown]
# ### Q3f)

# %% [markdown]
# _Harder_

# %% [markdown]
# Extract the _final 10_ entries of `y`:

# %%
# Your Q3f) code here

# %% [markdown]
# ### Solutions

# %% [markdown]
# Got to the end early? Want to check your solutions?
#
# Your trainer will be going over the solutions shortly.
#
# However, in the meanwhile, you can view the solutions to these exercises
# [here](1-exercises-solutions.ipynb).

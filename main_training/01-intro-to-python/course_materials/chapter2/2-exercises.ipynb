# %% [markdown]
# # Chapter 2 Exercises

# %% [markdown]
# Not all questions will require you to write code, you will be able to write
# your answers in the appropriate places. For code answers, write them out into
# the code cells provided.
#
# If you need help:
#
# * Look back through [chapter2/2-demo.ipynb](2-demo.ipynb)
#
# * Consult [chapter 2 of the course notes](../notes.pdf#e)
#
# * Ask for help from your trainer (unmute, message, or private message)

# %% [markdown]
# ### Q1a)

# %% [markdown]
# _Without_ running any code, if
# ```
# x = np.array([[1, 5],
#               [2, 6],
#               [3, 7],
#               [4, 8]])
# ```
# what value(s) would `x[1, 1]` return?

# %% [markdown]
# _Type your answer here_

# %%
# Check your answer to Q1a) by running me
import numpy as np

x = np.array([[1, 5],
              [2, 6],
              [3, 7],
              [4, 8]])

x[1, 1]

# %% [markdown]
# ### Q1b)

# %% [markdown]
# _Without_ running any code, if
# ```
# x = np.array([[1, 5],
#               [2, 6],
#               [3, 7],
#               [4, 8]])
# ```
# what value(s) would `x[2:, 1]` return?

# %% [markdown]
# _Type your answer here_

# %%
# Check your answer to Q1b) by running me
x = np.array([[1, 5],
              [2, 6],
              [3, 7],
              [4, 8]])

x[2:, 1]

# %% [markdown]
# ### Q1c)

# %% [markdown]
# _Without_ running any code, if
# ```
# x = np.array([[1, 5],
#               [2, 6],
#               [3, 7],
#               [4, 8]])
# ```
# what would `x.ndim` return?

# %% [markdown]
# _Type your answer here_

# %%
# Check your answer to Q1c) by running me
x = np.array([[1, 5],
              [2, 6],
              [3, 7],
              [4, 8]])

x.ndim

# %% [markdown]
# ### Q2)

# %% [markdown]
# Run the following code to import the `jrpyintroduction` course package and
# create a list `y`:

# %%
import jrpyintroduction as jrpy

# Create list object for this question
y = jrpy.get_numeric_list()

# %% [markdown]
# ### Q2a)

# %% [markdown]
# Convert our list `y` into a numpy array, and save it to a variable named `z`:

# %%
# Your Q2a) code here

# %% [markdown]
# ### Q2b)

# %% [markdown]
# What code would we use to find out the _type_ of data stored _in_ `z`?

# %%
# Your Q2b) code here

# %% [markdown]
# ### Q2c)

# %% [markdown]
# Cube (take to the power of 3) every entry in `z` (you don't need to save the
# output back to `z` here):

# %%
# Your Q2c) code here

# %% [markdown]
# ### Q2d)

# %% [markdown]
# Compute the arithmetic mean of the values in `z` using the `np.mean()` function
# (previously unseen). (Again, you don't need to save the output back to `z`
# here)

# %%
# Your Q2d) code here

# %% [markdown]
# ### Q2e)

# %% [markdown]
# Run the following code, using the previously unseen `.reshape()` method. Can
# you work out what this has done to `z`?

# %%
z = z.reshape(z.shape[0] // 4, 4)

# %%
# Explore new z here

# %% [markdown]
# ### Q3)

# %% [markdown]
# The UK's projected _total_ emissions (MtCO2e) for the years 2025-2029, under the
# Climate Change Committee's Balanced Pathway, are given in the following array.
#
# _(Source: the `Economy-wide data` sheet of the [CCC Seventh Carbon Budget dataset](https://www.theccc.org.uk/publication/the-seventh-carbon-budget/#publication-downloads) - "direct emissions total" for the Balanced Pathway, rounded to the nearest MtCO2e.)_

# %%
emissions = np.array([414, 396, 377, 355, 327])

# %% [markdown]
# ### Q3a)

# %% [markdown]
# Extract the _first_ element of `emissions` (the emissions for 2025) and store it
# in a variable called `starting_emissions`:

# %%
# Your Q3a) code here

# %% [markdown]
# ### Q3b)

# %% [markdown]
# Find the mean of the `emissions` values using the `np.mean()` function, and
# store it in a variable called `average_emissions`:

# %%
# Your Q3b) code here

# %% [markdown]
# ### Q3c)

# %% [markdown]
# Work out the difference between `starting_emissions` and `average_emissions`,
# and store it as `difference_to_average`:

# %%
# Your Q3c) code here

# %% [markdown]
# ### Q3d)

# %% [markdown]
# These emissions are in _millions_ of tonnes (MtCO2e). Define a variable
# `conversion_factor` equal to `1000`, then use it to convert every entry of
# `emissions` into _thousands_ of tonnes (ktCO2e):

# %%
# Your Q3d) code here

# %% [markdown]
# ### Solutions

# %% [markdown]
# Got to the end early? Want to check your solutions?
#
# Your trainer will be going over the solutions shortly.
#
# However, in the meanwhile, you can view the solutions to these exercises
# [here](2-exercises-solutions.ipynb).

# %% [markdown]
# # Chapter 2 Exercises

# %% [markdown]
# Not all questions will require you to write code, you will be able to write
# your answers in the appropriate places. For code answers, right them out into
# the code cells provided.
#
# If you need help:
#
# * Look back through [chapter2/2-demo.ipynb](2-demo.ipynb)
#
# * Ask for help from your trainer (unmute, message, or private message)

# %% [markdown]
# ### Q1)

# %% [markdown]
# This question will be easier to answer in VS Code or Positron.

# %% [markdown]
# ### Q1a)

# %% [markdown]
# In the example Python project created during the demo, you will find a
# requirements.txt with the project dependencies. Locate this file and inspect
# the contents.

# %% [markdown]
# ### Q1b)

# %% [markdown]
# Initialise a virtual environment using `venv` (call it whatever you like) and
# activate it.

# %% [markdown]
# ### Q1c)

# %% [markdown]
# Use `pip` to install the dependencies listed in the requirements.txt file.

# %% [markdown]
# ### Q1d)

# %% [markdown]
# Try running the code in main.py. In the command line, you can run:
#
# ```
# python main.py
# ```
#
# If your virtual environment has the correct dependencies installed, the code
# should run without error and produce an output plot called emissions.png.

# %% [markdown]
# ### Solutions

# %% [markdown]
# Got to the end early? Want to check your solutions?
#
# Your trainer will be going over the solutions shortly.
#
# However, in the meanwhile, you can view the solutions to these exercises
# [here](2-exercises-solutions.ipynb).

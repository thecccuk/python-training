# %% [markdown]
# # Chapter 4 Exercises

# %% [markdown]
# Not all questions will require you to write code, you will be able to write
# your answers in the appropriate places. For code answers, right them out into
# the code cells provided.
#
# If you need help:
#
# * Look back through [chapter4/4-demo.ipynb](4-demo.ipynb)
#
# * Ask for help from your trainer (unmute, message, or private message)

# %% [markdown]
# ### Q1)

# %% [markdown]
# This question will make use of an example script called `script-messy.py`

# %% [markdown]
# You can create a copy of this script in your current directory by running:

# %%
import jrpybestprac as jrbp

jrbp.examples.get_messy()

# %% [markdown]
# You can check the contents of this script with

# %%
# !cat script-messy.py

# %% [markdown]
# ### Q1a)

# %% [markdown]
# Run ruff against this script to identify where its formatting deviates from
# that expected by PEP8:

# %%
# Your Q1a) code here

# %% [markdown]
# ### Q1b)

# %% [markdown]
# Run ruff against this script to automatically fix as many formatting issues
# as possible:

# %%
# Your Q1b) code here

# %% [markdown]
# ### Q1c)

# %% [markdown]
# What other changes would you make to script-messy.py to resolve the remaining issues
# flagged by ruff?

# %% [markdown]
# List these changes below:
#
# _Your changes here_

# %% [markdown]
# ### Q2)

# %% [markdown]
# This question makes use of the `taxis` dataset:

# %%
import jrpybestprac as jrbp

taxis = jrbp.data.load_taxis()
taxis.head()

# %% [markdown]
# ### Q2a)

# %% [markdown]
# List any issues with the names of the variables and functions in the code below.

# %%
Taxi_rides_with_above_average_fare_dataframe = taxis.query("fare_amount > fare_amount.mean()")

# %% [markdown]
# _Write your issues with `Taxi_rides_with_above_average_fare_dataframe` here_

# %% [markdown]
# ### Q2b)

# %% [markdown]
# List any issues with the names of the variables and functions in the code below.

# %%
def AnalyseData(data):
    (
       data 
        .assign(trip_distance_miles=lambda x: x["trip_distance"] * 0.62)
        .query("passenger_count == 1")
        .plot(x="trip_distance_miles", y="tip_amount", kind="scatter")
    )

# %% [markdown]
# _Write your issues with `AnalyseData` here_

# %% [markdown]
# ### Solutions

# %% [markdown]
# Got to the end early? Want to check your solutions?
#
# Your trainer will be going over the solutions shortly.
#
# However, in the meanwhile, you can view the solutions to these exercises
# [here](4-exercises-solutions.ipynb).

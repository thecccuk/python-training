# %% [markdown]
# # Chapter 2 Exercises

# %% [markdown]
# Not all questions will require you to write code, you will be able to write
# your answers in the appropriate places. For code answers, write them out into
# the code cells provided.
#
# If you need help:
#
# * Look back through [chapter2/2-demo.ipynb](2-demo.ipynb)
#
# * Consult the [course notes](../notes.pdf)
#
# * Ask for help from your trainer (unmute, message, or private message)

# %% [markdown]
# ### Q1a)

# %% [markdown]
# Create a numpy array containing the values from this list and store it in the
# variable `array1`.
#
# _Hint_: Use `np.array` to create a numpy array

# %%
import numpy as np

values = [1, 4, 3, 5]

# Your Q1A) code here

# %% [markdown]
# ### Q1b)

# %% [markdown]
# Now determine the `type` of your array and whether it is an instance of that
# type.
#
# _Hint_: because we imported numpy as `np`, you'll need to use `np.className`
# instead of `numpy.className` in your call to `isinstance()`

# %%
# Your Q1B) code here

# %% [markdown]
# In much of the code we write in this course, you will use `className(arguments)`
# to create a class instance and the type of the created object will match the
# class name. `array()` is a function in numpy, rather than a class constructor.

# %% [markdown]
# ### Q2)

# %% [markdown]
# Rewrite our `Car` class allowing the user to pass a `year` argument into
# the constructor (in addition to the `model` and `mpg` arguments in the
# demo script).
#
# `year` should be stored as an attribute.

# %%
# Your Q2) code here
class Car():
    def __init__(self, model, mpg):
        self.model = model
        self.mpg = mpg

# %% [markdown]
# Test it with the following code:

# %%
car = Car("VW beetle", 10, 1971)
car.year

# %% [markdown]
# ### Q3)

# %% [markdown]
# The following code is broken, can you fix it?

# %%
class Wolf():
    def __init__(is_bad):
        self.is_bad = is_bad
    
    def greet(self):
        if is_bad:
            greeting = "I'll huff and I'll puff and I'll blow your house down"
        else:
            greeting = "Hi"
        print(greeting)

# %%
# Your Q3) code here

# %% [markdown]
# Once fixed, the following code should run without any errors:

# %%
wolf1 = Wolf(is_bad=True)
wolf1.greet() # Should print "I'll huff and ..."

# %%
wolf2 = Wolf(is_bad=False)
wolf2.greet() # Should print "Hi"

# %% [markdown]
# ### Solutions

# %% [markdown]
# Got to the end early? Want to check your solutions?
#
# Your trainer will be going over the solutions shortly.
#
# However, in the meanwhile, you can view the solutions to these exercises
# [here](2-exercises-solutions.ipynb).
